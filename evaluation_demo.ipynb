# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from utils import *

array = list(range(100))
array2 = np.random.randint(2,26, size=100)
array3 = array2.copy()

def get_absolute_difference(array1, array2):
    result = []
    for i in range(len(array1)):
        diff = abs(array1[i] - array2[i])
        result.append(diff)
    return result


def add_random_quantity(array):
    for i in range(len(array)):
        array[i] += random.randint(1, 6)
    return array

array3 = add_random_quantity(array3)
array_diff = get_absolute_difference(array2, array3)

# %%
plot_avg_steps_difference(array2, array3)

# %%
print(compute_percentage_difference(array2, array3))
# Out:
# 23.41

# %%
x = 20
y = 80
tot = 100


plot_success_rate(x,y,tot)
