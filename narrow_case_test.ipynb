# %% [markdown]
# # Main testing

# %%
import gym
import minihack
import numpy as np
import math
import matplotlib.pyplot as plt
import IPython.display as display
from typing import Tuple, List
from utils import *
from algorithms import *
from logic import *

# %% [markdown]
# ## Creation of the environment

# %%
env = gym.make("MiniHack-River-Narrow-v0", observation_keys=("chars", "pixel"))
state = env.reset()
env.render()
# Out:
# Hello Agent, welcome to NetHack!  You are a chaotic male human Rogue.
#
#
#
#
#
#
#
#                           .............
#                           ...........
#                           .........`
#                           .........
#                           .....
#                           @.`
#                           .....
#
#
#
#
#
#
#
# Agent the Footpad              St:18 Dx:13 Co:15 In:9 Wi:12 Ch:8 Chaotic S:0
# Dlvl:1 $:0 HP:12(12) Pw:2(2) AC:7 Xp:1/0

# %% [markdown]
# Printing the structure of the map and the graphic visualization

# %%
state['chars'].shape, state['pixel'].shape
# Out:
# ((21, 79), (336, 1264, 3))

# %%
plt.imshow(state['pixel'][100:250, 400:750]) #Immagine ristretta con range [y][x]

# %%
new_river_position = push_one_boulder_into_river(state, env)
# Out:
# [(9, 35, inf), (12, 28, inf)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /root/Minihack_Crossing_River/narrow_case_test.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/root/Minihack_Crossing_River/narrow_case_test.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> new_river_position = push_one_boulder_into_river(state, env)
#
# File ~/Minihack_Crossing_River/algorithms.py:208, in push_one_boulder_into_river(state, env, target, hasBoulder)
#     204     final_position = target
#     207 #Calculating the path from the boulder to the river shortest distance
# --> 208 path_boulder_river = a_star(game_map, coordinates_min_boulder, river_positions,final_position, hasBoulder,get_optimal_distance_point_to_point)
#     209 path_boulder_river.append(final_position)
#     211 #Calculating the position in which the agent have to be in order to push correctly the boulder into the river
#
# File ~/Minihack_Crossing_River/algorithms.py:55, in a_star(game_map, start, river_positions, target, hasBoulder, h)
#      53 #Scores of the start node
#      54 g_start = 0 #g score of the start node
# ---> 55 f_start= h(start, target) #f score of the start node
#      57 #Dictionary with the g score of each node
#      58 g_scores[start] = g_start #Insert the g score of the start node in the dictionary
#
# File ~/Minihack_Crossing_River/algorithms.py:138, in get_optimal_distance_point_to_point(start, target)
#     127 def get_optimal_distance_point_to_point(start: Tuple[int, int], target : Tuple[int,int]) -> int:
#     128     """
#     129     Calculate the optimal distance between two points.
#     130
#    (...)
#     136         int: The optimal distance between the two points.
#     137     """
# --> 138     targetX = target[0]
#     139     targetY = target[1]
#     140     dist_point_to_point = chebyshev_dist(start[0],start[1], targetX, targetY)
#
# IndexError: tuple index out of range

# %%
new_river_position

# %%
new_river_position = push_one_boulder_into_river(state, env, new_river_position)
